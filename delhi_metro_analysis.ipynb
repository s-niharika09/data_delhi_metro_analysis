# %% [markdown]
# # Importing Pandas and Reading JSON File

# %%
import pandas as pd

df = pd.read_json(r"D:\delhi_metro_analysis\delhi_metro_trips.json")
print(df.head(10))
print("The json dataset has been successfully loaded")
# Out:
#    TripID       Date         From_Station            To_Station  Distance_km  \
# 0   59771 2022-05-08             Inderlok         Kashmere Gate        12.94
# 1   21363 2023-01-12           Model Town        Dilshad Garden         2.33
# 2  127325 2023-07-13     Kashmere Gate     Netaji Subhash Place         5.56
# 3  140510 2022-11-10        Chandni Chowk             Hauz Khas         4.02
# 4  144298 2022-11-06          Rajiv Chowk        Kalkaji Mandir         9.66
# 5   96371 2024-07-10       Kalkaji Mandir          Shivaji Park         3.91
# 6   49743 2022-09-02          Mandi House          Jasola Vihar         1.49
# 7   47390 2023-12-07          Mandi House   Central Secretariat         7.38
# 8   58379 2024-05-05                AIIMS         Chandni Chowk         2.57
# 9   69048 2022-07-05            New Delhi          Jasola Vihar         7.58
#
#      Fare  Cost_per_passenger  Passengers   Ticket_Type      Remarks
# 0   77.99               18.27        13.0    Smart Card  maintenance
# 1   35.89               83.71        15.0  Tourist Card  maintenance
# 2   64.35               43.70         9.0        Single     off-peak
# 3  144.13               14.98        27.0           NaN  maintenance
# 4  104.96               83.84        23.0        Single     off-peak
# 5   29.20               30.64        22.0  Tourist Card          NaN
# 6  175.32               33.45        14.0  Tourist Card         peak
# 7  167.59               50.69        18.0  Tourist Card     festival
# 8  125.25               81.71        24.0        Single      weekend
# 9  151.39               37.76        19.0  Tourist Card         peak
# The json dataset has been successfully loaded

# %% [markdown]
# # df.info() Gives Summary of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TripID              10000 non-null  int64
#  1   Date                10000 non-null  datetime64[us]
#  2   From_Station        10000 non-null  str
#  3   To_Station          10000 non-null  str
#  4   Distance_km         10000 non-null  float64
#  5   Fare                10000 non-null  float64
#  6   Cost_per_passenger  10000 non-null  float64
#  7   Passengers          9910 non-null   float64
#  8   Ticket_Type         9888 non-null   str
#  9   Remarks             8246 non-null   str
# dtypes: datetime64[us](1), float64(4), int64(1), str(4)
# memory usage: 859.4 KB

# %% [markdown]
# # Revoming Extra Spaces in Station_Names using .Strip() method and Standardizing Station_Names

# %%
df["From_Station"] = df["From_Station"].str.strip().str.replace(r"\s+", " ", regex= True).str.upper()
print(df["From_Station"])
df["To_Station"] = df["To_Station"].str.strip().str.replace(r"\s+", " ", regex= True).str.upper()
print(df["To_Station"])
df.head()
# Out:
# 0                INDERLOK
# 1              MODEL TOWN
# 2           KASHMERE GATE
# 3           CHANDNI CHOWK
# 4             RAJIV CHOWK
#               ...
# 9995          RAJIV CHOWK
# 9996       KALKAJI MANDIR
# 9997            HAUZ KHAS
# 9998          RAJIV CHOWK
# 9999    NOIDA CITY CENTRE
# Name: From_Station, Length: 10000, dtype: str
# 0              KASHMERE GATE
# 1             DILSHAD GARDEN
# 2       NETAJI SUBHASH PLACE
# 3                  HAUZ KHAS
# 4             KALKAJI MANDIR
#                 ...
# 9995            SHIVAJI PARK
# 9996             KIRTI NAGAR
# 9997     CENTRAL SECRETARIAT
# 9998               OLD DELHI
# 9999          JANAKPURI WEST
# Name: To_Station, Length: 10000, dtype: str
#    TripID       Date   From_Station            To_Station  Distance_km  \
# 0   59771 2022-05-08       INDERLOK         KASHMERE GATE        12.94
# 1   21363 2023-01-12     MODEL TOWN        DILSHAD GARDEN         2.33
# 2  127325 2023-07-13  KASHMERE GATE  NETAJI SUBHASH PLACE         5.56
# 3  140510 2022-11-10  CHANDNI CHOWK             HAUZ KHAS         4.02
# 4  144298 2022-11-06    RAJIV CHOWK        KALKAJI MANDIR         9.66
#
#      Fare  Cost_per_passenger  Passengers   Ticket_Type      Remarks
# 0   77.99               18.27        13.0    Smart Card  maintenance
# 1   35.89               83.71        15.0  Tourist Card  maintenance
# 2   64.35               43.70         9.0        Single     off-peak
# 3  144.13               14.98        27.0           NaN  maintenance
# 4  104.96               83.84        23.0        Single     off-peak

# %% [markdown]
# # Handling Missing Values

# %%
print(df["Ticket_Type"].isnull().sum())
print(df["Ticket_Type"].unique())
df["Ticket_Type"] = df["Ticket_Type"].fillna(df["Ticket_Type"].mode()[0])

print(df["Passengers"].isnull().sum())
print(df["Passengers"].unique())
df["Passengers"] = df["Passengers"].fillna(df["Passengers"].median())

print(df["Remarks"].isnull().sum())
print(df["Remarks"].unique())
df["Remarks"] = df["Remarks"].fillna(df["Remarks"].mode()[0])
# Out:
# 112
# <StringArray>
# ['Smart Card', 'Tourist Card', 'Single', nan]
# Length: 4, dtype: str
# 90
# [13. 15.  9. 27. 23. 22. 14. 18. 24. 19. 16. 21. 11. 26. 25. 28. 20. 17.
#  31. 12.  8. 32. 34. 33. 35. 29. 30. nan 10.  7.  5. 36. 37.]
# 1754
# <StringArray>
# ['maintenance', 'off-peak', nan, 'peak', 'festival', 'weekend']
# Length: 6, dtype: str

# %% [markdown]
# # Converting Date columns into DateTime Format

# %%
df["Date"].dtypes
df.info()
df.head()
# There is no requirement to convert because Date column is in DateTime Format
# Out:
# <class 'pandas.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TripID              10000 non-null  int64
#  1   Date                10000 non-null  datetime64[us]
#  2   From_Station        10000 non-null  str
#  3   To_Station          10000 non-null  str
#  4   Distance_km         10000 non-null  float64
#  5   Fare                10000 non-null  float64
#  6   Cost_per_passenger  10000 non-null  float64
#  7   Passengers          10000 non-null  float64
#  8   Ticket_Type         10000 non-null  str
#  9   Remarks             10000 non-null  str
# dtypes: datetime64[us](1), float64(4), int64(1), str(4)
# memory usage: 859.4 KB
#    TripID       Date   From_Station            To_Station  Distance_km  \
# 0   59771 2022-05-08       INDERLOK         KASHMERE GATE        12.94
# 1   21363 2023-01-12     MODEL TOWN        DILSHAD GARDEN         2.33
# 2  127325 2023-07-13  KASHMERE GATE  NETAJI SUBHASH PLACE         5.56
# 3  140510 2022-11-10  CHANDNI CHOWK             HAUZ KHAS         4.02
# 4  144298 2022-11-06    RAJIV CHOWK        KALKAJI MANDIR         9.66
#
#      Fare  Cost_per_passenger  Passengers   Ticket_Type      Remarks
# 0   77.99               18.27        13.0    Smart Card  maintenance
# 1   35.89               83.71        15.0  Tourist Card  maintenance
# 2   64.35               43.70         9.0        Single     off-peak
# 3  144.13               14.98        27.0  Tourist Card  maintenance
# 4  104.96               83.84        23.0        Single     off-peak

# %% [markdown]
# # Changing Column Name

# %%
df.rename({"Date":"Jounery_Date"},axis=1,inplace=True)

# %% [markdown]
# # Ensuring Numeric Columns are Correctly Formatted

# %%
# Converting Passengers from Float dtype to Int dtype
df["Passengers"] = df["Passengers"].round().astype(int)
df.head()
# Out:
#    TripID Jounery_Date   From_Station            To_Station  Distance_km  \
# 0   59771   2022-05-08       INDERLOK         KASHMERE GATE        12.94
# 1   21363   2023-01-12     MODEL TOWN        DILSHAD GARDEN         2.33
# 2  127325   2023-07-13  KASHMERE GATE  NETAJI SUBHASH PLACE         5.56
# 3  140510   2022-11-10  CHANDNI CHOWK             HAUZ KHAS         4.02
# 4  144298   2022-11-06    RAJIV CHOWK        KALKAJI MANDIR         9.66
#
#      Fare  Cost_per_passenger  Passengers   Ticket_Type      Remarks
# 0   77.99               18.27          13    Smart Card  maintenance
# 1   35.89               83.71          15  Tourist Card  maintenance
# 2   64.35               43.70           9        Single     off-peak
# 3  144.13               14.98          27  Tourist Card  maintenance
# 4  104.96               83.84          23        Single     off-peak

# %% [markdown]
# # Converting From JSON File To CSV File

# %%
# From JSON 
#df = pd.read_json(r"D:\delhi_metro_analysis\delhi_metro_trips.json")
# To Cleaned CSV
df_cleaned = df.copy()
df_cleaned.to_csv(r"D:\delhi_metro_analysis\delhi_metro_trips.csv", index=False)
print("Data is Cleaned and Converted Into CVS File Successfully")
# Out:
# Data is Cleaned and Converted Into CVS File Successfully

# %% [markdown]
# # Database Creation (SQL)

# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\Users\Niharika\AppData\Local\Programs\Python\Python313\Lib\site-packages (9.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley"
)

if conn.is_connected():
    print("Connection Successful!")  

cursor = conn.cursor() 
cursor.execute("CREATE DATABaSE IF NOT EXISTS delhi_metro")

cursor.close()
conn.close()
# Out:
# Connection Successful!

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro",
    allow_local_infile=True
)  

cursor = conn.cursor
print("Connected to delhi_metro database")
# Out:
# Connected to delhi_metro database

# %% [markdown]
# # Creating a Structured table Schema

# %%
#database="delhi_metro"

cursor=conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS metro_trips(
    TripID INT,
    Journey_Date DATETIME,
    From_Station VARCHAR(50),
    To_Station VARCHAR(50),
    Distance_km FLOAT,
    Fare FLOAT,
    Cost_per_passenger FLOAT,
    Passengers INT,
    Ticket_Type VARCHAR(50),
    Remarks VARCHAR(100)
    )              
 """)

conn.commit()

# %% [markdown]
# # Importing cleaned data into the SQL table

# %%
# Convert dataframe to list of tuples

import pandas as pd
import mysql.connector

# Load CSV
df = pd.read_csv("D:/delhi_metro_analysis/delhi_metro_trips.csv")

#check data
print(df.head())

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)
cursor = conn.cursor()

data = list(df.itertuples(index=False, name=None))

query = """
INSERT INTO metro_trips(
    TripID,
    Journey_Date,
    From_Station,
    To_Station,
    Distance_km,
    Fare,
    Cost_per_passenger,
    Passengers,
    Ticket_Type,
    Remarks
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

cursor.executemany(query, data)
conn.commit()

print("Data inserted successfully!")
# Out:
#    TripID Jounery_Date   From_Station            To_Station  Distance_km  \
# 0   59771   2022-05-08       INDERLOK         KASHMERE GATE        12.94
# 1   21363   2023-01-12     MODEL TOWN        DILSHAD GARDEN         2.33
# 2  127325   2023-07-13  KASHMERE GATE  NETAJI SUBHASH PLACE         5.56
# 3  140510   2022-11-10  CHANDNI CHOWK             HAUZ KHAS         4.02
# 4  144298   2022-11-06    RAJIV CHOWK        KALKAJI MANDIR         9.66
#
#      Fare  Cost_per_passenger  Passengers   Ticket_Type      Remarks
# 0   77.99               18.27          13    Smart Card  maintenance
# 1   35.89               83.71          15  Tourist Card  maintenance
# 2   64.35               43.70           9        Single     off-peak
# 3  144.13               14.98          27  Tourist Card  maintenance
# 4  104.96               83.84          23        Single     off-peak
# Data inserted successfully!

# %% [markdown]
# # Creating Indexes for Faster Query Execution

# %%
#cursor.execute("""
#CREATE INDEX idx_Tripss
#ON metro_trips (TripID)             
#""")

#cursor.execute("""
#CREATE INDEX IF NOT EXISTS idx_Stations_Search
#ON metro_trips (From_Station, To_Station, Journey_Date)
#""")

#cursor.execute("""
#CREATE INDEX IF NOT EXISTS idx_Journey_Dates
#ON metro_trips (Journey_Date)             
#""")

#cursor.execute("""
#CREATE INDEX IF NOT EXISTS idx_Ticket_Types
#ON metro_trips (Ticket_Type)             
#""")

#cursor.execute("""
#CREATE INDEX IF NOT EXISTS idx_Passengerss
#ON metro_trips (Passengers)             
#""")

#cursor.execute("""
#CREATE INDEX IF NOT EXISTS idx_Remarkss
#ON metro_trips (Remarks)             
#""")

#conn.commit()

# %%
#cursor.execute("SHOW INDEX FROM metro_trips")
#for row in cursor.fetchall():
#    print(row[2])   # index name

# %%
#cursor.execute("SHOW INDEX FROM metro_trips")
#indexes = set([row[2] for row in cursor.fetchall()])

#for idx in indexes:
#    if idx != "PRIMARY":
#        cursor.execute(f"DROP INDEX {idx} ON metro_trips")

#conn.commit()
#print("All non-primary indexes dropped")

# %%
#import mysql.connector

#conn = mysql.connector.connect(
#   host="localhost",
#    user="root",
#    password="sakiley",
#    database="delhi_metro"
#)

#cursor = conn.cursor()

#cursor.execute("""
#ALTER TABLE metro_trips
#DROP INDEX idx_Trip,
#DROP INDEX idx_Station_Search,
#DROP INDEX idx_Journey_Date,
#DROP INDEX idx_Ticket_Type,
#DROP INDEX idx_Passengers,
#DROP INDEX idx_Remarks,
#DROP INDEX idx_TripS,
#DROP INDEX idx_Tripss,
#DROP INDEX idx_Stations_Search,
#DROP INDEX idx_Journey_Dates,
#DROP INDEX idx_Ticket_Types,
#DROP INDEX idx_Passengerss,
#DROP INDEX idx_Remarkss
#""")

#conn.commit()

# %%
cursor.execute("SHOW INDEX FROM metro_trips")
existing_indexes = [row[2] for row in cursor.fetchall()]

if "idx_route" not in existing_indexes:
    cursor.execute("CREATE INDEX idx_route ON metro_trips (From_Station, To_Station)")
if "idx_journey_date" not in existing_indexes:
    cursor.execute("CREATE INDEX idx_journey_date ON metro_trips (Journey_Date)")
if "idx_ticket" not in existing_indexes:
    cursor.execute("CREATE INDEX idx_ticket ON metro_trips (Ticket_Type)")

conn.commit()

# %% [markdown]
# # Data Analysis Using SQL

# %% [markdown]
# # Route Analysis

# %% [markdown]
# 1.Which metro routes have the highest passenger traffic?

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT 
    From_Station,
    To_Station,
    SUM(Passengers) as total_passengers
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY total_passengers DESC
LIMIT 5;    
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\4220151137.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#   From_Station         To_Station  total_passengers
# 0  RAJIV CHOWK      CHANDNI CHOWK           24612.0
# 1  RAJIV CHOWK          OLD DELHI           22554.0
# 2  RAJIV CHOWK  NOIDA CITY CENTRE           22470.0
# 3  RAJIV CHOWK        KIRTI NAGAR           22022.0
# 4  RAJIV CHOWK       JASOLA VIHAR           21840.0

# %% [markdown]
# 2.Which routes generate the highest total revenue?

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    To_Station,
    Sum(Fare * Passengers) as total_revenue
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY total_revenue DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2582124677.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#   From_Station      To_Station  total_revenue
# 0  RAJIV CHOWK   CHANDNI CHOWK   2.754595e+06
# 1  RAJIV CHOWK  KALKAJI MANDIR   2.301865e+06
# 2  RAJIV CHOWK       OLD DELHI   2.297268e+06
# 3  RAJIV CHOWK       HAUZ KHAS   2.274953e+06
# 4  RAJIV CHOWK           AIIMS   2.267086e+06

# %% [markdown]
# 3.What is the average fare for each route?

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    To_Station,
    AVG(Fare) as average_fare
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY average_fare DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\1211053071.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#      From_Station      To_Station  average_fare
# 0     LAXMI NAGAR     LAXMI NAGAR    167.983332
# 1  DILSHAD GARDEN  DILSHAD GARDEN    153.259995
# 2       HAUZ KHAS  PRAGATI MAIDAN    140.597692
# 3   CHANDNI CHOWK     LAXMI NAGAR    140.508000
# 4        INDERLOK      MODEL TOWN    134.576818

# %% [markdown]
# 4.Which routes have the longest travel distances?

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    To_Station,
    MAX(Distance_km) as maximum_distance
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY maximum_distance DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\1692512676.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#      From_Station      To_Station  maximum_distance
# 0       NEW DELHI     MANDI HOUSE             45.69
# 1       HAUZ KHAS  DILSHAD GARDEN             43.94
# 2      MODEL TOWN     MANDI HOUSE             43.38
# 3  JANAKPURI WEST     LAXMI NAGAR             42.49
# 4     MANDI HOUSE       HAUZ KHAS             40.23

# %% [markdown]
# # Station Analysis

# %% [markdown]
# 5.Which stations have the highest number of trip departures?

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    COUNT(From_Station) as count_of_maximum_departures
FROM metro_trips
GROUP BY From_Station
ORDER BY count_of_maximum_departures DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\1496272098.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#         From_Station  count_of_maximum_departures
# 0        RAJIV CHOWK                        23716
# 1  NOIDA CITY CENTRE                        17318
# 2          NEW DELHI                        11732
# 3        MANDI HOUSE                        11648
# 4      CHANDNI CHOWK                         6300

# %% [markdown]
# 5.a.Total departure analysis:

# %%
import pandas as pd

df = pd.read_sql_query("""
SELECT
    station,
    SUM(departures) as total_departures,
    SUM(arrivals) as total_arrivals
FROM(
    SELECT From_Station as station, COUNT(*) as departures, 0 as arrivals
    FROM metro_trips
    GROUP BY From_Station
                       
UNION
    
    SELECT To_Station as station, 0 as arrivals, COUNT(*) as arrrival
    FROM metro_trips
    GROUP BY To_Station
)AS combined
GROUP BY station
ORDER BY total_departures DESC;
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\1687491225.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#                  station  total_departures  total_arrivals
# 0            RAJIV CHOWK           23716.0          5376.0
# 1      NOIDA CITY CENTRE           17318.0          5922.0
# 2              NEW DELHI           11732.0          5670.0
# 3            MANDI HOUSE           11648.0          5838.0
# 4          CHANDNI CHOWK            6300.0          6076.0
# 5               INDERLOK            6258.0          6006.0
# 6          KASHMERE GATE            5950.0          5754.0
# 7             MODEL TOWN            5950.0          5544.0
# 8                  AIIMS            5922.0          5838.0
# 9            LAXMI NAGAR            5908.0          6328.0
# 10          JASOLA VIHAR            5768.0          6370.0
# 11        KALKAJI MANDIR            5768.0          5964.0
# 12        DILSHAD GARDEN            5754.0          5838.0
# 13             HAUZ KHAS            5698.0          5838.0
# 14   CENTRAL SECRETARIAT            5614.0          5768.0
# 15        JANAKPURI WEST            5348.0          5544.0
# 16        RAJOURI GARDEN            5348.0          6118.0
# 17       BARAKHAMBA ROAD               0.0          6188.0
# 18           KIRTI NAGAR               0.0          5796.0
# 19  NETAJI SUBHASH PLACE               0.0          6006.0
# 20             OLD DELHI               0.0          5684.0
# 21        PRAGATI MAIDAN               0.0          5474.0
# 22          PUNJABI BAGH               0.0          5418.0
# 23          SHIVAJI PARK               0.0          5642.0

# %% [markdown]
# 6. Which stations receive the highest number of passengers?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor

import pandas as pd

df = pd.read_sql_query("""
SELECT
    To_Station,
    SUM(Passengers) as maximum_passengers
FROM metro_trips
GROUP BY To_Station
ORDER BY maximum_passengers DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\3131274981.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#         To_Station  maximum_passengers
# 0     JASOLA VIHAR            127316.0
# 1      LAXMI NAGAR            126406.0
# 2    CHANDNI CHOWK            123900.0
# 3   RAJOURI GARDEN            123158.0
# 4  BARAKHAMBA ROAD            122990.0

# %% [markdown]
# 7. What are the top 10 most frequently used metro stations?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    station,
    SUM(total_passengers) AS total_usage
FROM (
    SELECT From_Station AS station, SUM(Passengers) AS total_passengers
    FROM metro_trips
    GROUP BY From_Station

    UNION ALL

    SELECT To_Station AS station, SUM(Passengers) AS total_passengers
    FROM metro_trips
    GROUP BY To_Station
) AS combined
GROUP BY station
ORDER BY total_usage DESC
LIMIT 10;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2861967125.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#              station  total_usage
# 0        RAJIV CHOWK     579502.0
# 1  NOIDA CITY CENTRE     464058.0
# 2        MANDI HOUSE     350826.0
# 3          NEW DELHI     349440.0
# 4      CHANDNI CHOWK     251692.0
# 5        LAXMI NAGAR     245490.0
# 6           INDERLOK     244846.0
# 7       JASOLA VIHAR     243894.0
# 8     KALKAJI MANDIR     237776.0
# 9              AIIMS     235466.0

# %% [markdown]
# 8. Which station pairs are most frequently used for travel?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    To_Station,
    SUM(Passengers) as frequently_travelled
FROM metro_trips
GROUP BY From_Station,To_Station
ORDER BY frequently_travelled DESC
LIMIT 10;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2414946039.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#   From_Station            To_Station  frequently_travelled
# 0  RAJIV CHOWK         CHANDNI CHOWK               24612.0
# 1  RAJIV CHOWK             OLD DELHI               22554.0
# 2  RAJIV CHOWK     NOIDA CITY CENTRE               22470.0
# 3  RAJIV CHOWK           KIRTI NAGAR               22022.0
# 4  RAJIV CHOWK          JASOLA VIHAR               21840.0
# 5  RAJIV CHOWK        JANAKPURI WEST               21378.0
# 6  RAJIV CHOWK                 AIIMS               21336.0
# 7  RAJIV CHOWK  NETAJI SUBHASH PLACE               21210.0
# 8  RAJIV CHOWK              INDERLOK               21014.0
# 9  RAJIV CHOWK        KALKAJI MANDIR               20650.0

# %% [markdown]
# # Revenue Analysis

# %% [markdown]
# 9. What is the total revenue generated from all trips?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT SUM(Passengers*Fare) as total_revenue
FROM metro_trips
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\3622585313.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#    total_revenue
# 0   2.924514e+08

# %% [markdown]
# 10. What is the average fare per trip?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT
    TripID,
    AVG(Passengers*Fare) as average_fare
FROM metro_trips
GROUP BY TripID
ORDER BY average_fare
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2335755524.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#    TripID  average_fare
# 0  131069    103.860000
# 1  136189    103.999996
# 2  111868    116.239998
# 3   93169    130.130003
# 4  119314    143.130003

# %% [markdown]
# 11. Which routes generate the highest revenue per kilometer?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT
    From_Station,
    To_Station,
    SUM(Passengers * Fare) / SUM(Distance_km) as revenue_per_km
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY revenue_per_km DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\3678066459.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#           From_Station       To_Station  revenue_per_km
# 0       DILSHAD GARDEN   DILSHAD GARDEN     6385.832851
# 1       KALKAJI MANDIR  BARAKHAMBA ROAD      955.695274
# 2  CENTRAL SECRETARIAT   PRAGATI MAIDAN      952.333351
# 3                AIIMS            AIIMS      767.579280
# 4             INDERLOK   DILSHAD GARDEN      705.914572

# %% [markdown]
# 12. Which ticket type generates the highest revenue?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT
    Ticket_Type,
    SUM(Passengers * Cost_per_passenger) as ticket_type_revenue
FROM metro_trips
GROUP BY Ticket_Type
ORDER BY ticket_type_revenue DESC
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\882802810.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#     Ticket_Type  ticket_type_revenue
# 0  Tourist Card         8.706699e+07
# 1        Single         4.499037e+07
# 2    Smart Card         4.397948e+07

# %% [markdown]
# # Passenger Analysis

# %% [markdown]
# 13. What is the average number of passengers per trip?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT AVG(Passengers) as average_passengers
FROM metro_trips
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\352590382.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#    average_passengers
# 0             20.0178

# %% [markdown]
# 14. Which trips recorded the highest passenger counts?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    From_Station,
    To_Station,                  
    SUM(Passengers) as max_passengers_count
FROM metro_trips
GROUP BY From_Station, To_Station
ORDER BY max_passengers_count DESC
LIMIT 5;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\650772021.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#   From_Station         To_Station  max_passengers_count
# 0  RAJIV CHOWK      CHANDNI CHOWK               24612.0
# 1  RAJIV CHOWK          OLD DELHI               22554.0
# 2  RAJIV CHOWK  NOIDA CITY CENTRE               22470.0
# 3  RAJIV CHOWK        KIRTI NAGAR               22022.0
# 4  RAJIV CHOWK       JASOLA VIHAR               21840.0

# %% [markdown]
# 15. What is the passenger distribution by ticket type?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    Ticket_Type,
    SUM(Passengers) AS total_passengers,
    (SUM(Passengers) * 100.0 / (SELECT SUM(Passengers) FROM metro_trips)) AS percentage_distribution
FROM metro_trips
GROUP BY Ticket_Type
ORDER BY total_passengers DESC;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\1590392111.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#     Ticket_Type  total_passengers  percentage_distribution
# 0  Tourist Card         1390844.0                 49.62883
# 1        Single          710598.0                 25.35593
# 2    Smart Card          701050.0                 25.01524

# %% [markdown]
# 16. What is the total passenger count for each station?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    From_Station,
    SUM(Passengers) AS total_passengers
FROM metro_trips
GROUP BY From_Station
ORDER BY total_passengers DESC;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\3312645206.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#            From_Station  total_passengers
# 0           RAJIV CHOWK          472192.0
# 1     NOIDA CITY CENTRE          345268.0
# 2           MANDI HOUSE          236684.0
# 3             NEW DELHI          234682.0
# 4         CHANDNI CHOWK          127792.0
# 5              INDERLOK          124894.0
# 6           LAXMI NAGAR          119084.0
# 7         KASHMERE GATE          118468.0
# 8                 AIIMS          118244.0
# 9            MODEL TOWN          117432.0
# 10         JASOLA VIHAR          116578.0
# 11       KALKAJI MANDIR          115850.0
# 12            HAUZ KHAS          115150.0
# 13       DILSHAD GARDEN          114646.0
# 14  CENTRAL SECRETARIAT          113176.0
# 15       JANAKPURI WEST          106274.0
# 16       RAJOURI GARDEN          106078.0

# %% [markdown]
# # Travel Pattern Analysis

# %% [markdown]
# 17. How many trips occur during peak, off-peak, festival, and weekend conditions?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    Remarks,
    COUNT(*) AS total_trips
FROM metro_trips
GROUP BY Remarks
ORDER BY total_trips DESC;
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2630461847.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#        Remarks  total_trips
# 0     festival        47978
# 1     off-peak        23170
# 2      weekend        23114
# 3  maintenance        23086
# 4         peak        22652

# %% [markdown]
# 18. Which travel condition generates the highest revenue?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    Remarks,
    SUM(Passengers * Cost_per_passenger) AS highest_revenue
FROM metro_trips
GROUP BY Remarks
ORDER BY highest_revenue DESC;   
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\3763339169.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#        Remarks  highest_revenue
# 0     festival     6.025861e+07
# 1      weekend     2.939865e+07
# 2     off-peak     2.930229e+07
# 3  maintenance     2.882278e+07
# 4         peak     2.825450e+07

# %% [markdown]
# 19. What is the monthly passenger trend across the dataset?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    MONTHNAME(Journey_Date) AS month,
    SUM(Passengers) AS monthly_trend
FROM metro_trips
GROUP BY MONTHNAME(Journey_Date)
ORDER BY monthly_trend DESC;   
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\244357845.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#         month  monthly_trend
# 0     January       244636.0
# 1       April       243306.0
# 2         May       241528.0
# 3    December       241136.0
# 4        July       239722.0
# 5   September       238154.0
# 6     October       231070.0
# 7      August       229586.0
# 8       March       228634.0
# 9    February       223146.0
# 10       June       221480.0
# 11   November       220094.0

# %% [markdown]
# 20. Which travel condition has the highest average passenger count per trip?

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sakiley",
    database="delhi_metro"
)  

cursor = conn.cursor()

import pandas as pd

df = pd.read_sql_query("""
SELECT 
    Remarks,
    AVG(Passengers) AS highest_avg_passengers
FROM metro_trips
GROUP BY Remarks
ORDER BY highest_avg_passengers DESC;                    
""", conn)

print(df)
# Out:
# C:\Users\Niharika\AppData\Local\Temp\ipykernel_8088\2094572823.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("""
#        Remarks  highest_avg_passengers
# 0     off-peak                 20.2211
# 1     festival                 20.0131
# 2  maintenance                 19.9921
# 3         peak                 19.9506
# 4      weekend                 19.9152
